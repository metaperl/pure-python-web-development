# %%
import pandas as pd
import hvplot.pandas
import panel as pn


csv_file = "https://raw.githubusercontent.com/metaperl/pure-python-web-development/main/examples/covid-ticker-data/data/ticker-data.csv"
ticker_df = pd.read_csv(csv_file, parse_dates=["Date"], index_col="Date")
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
import hvplot.pandas

# %%
pton_df = ticker_df[ticker_df['Ticker'] == 'PTON']

# %%
pton_df.hvplot.line(x='Date', y='Close')
# Out:
# C:\code\pure-python-web-development\venv\Lib\site-packages\holoviews\core\data\pandas.py:39: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   return dataset.data.dtypes[idx].type
# C:\code\pure-python-web-development\venv\Lib\site-packages\holoviews\core\data\pandas.py:39: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   return dataset.data.dtypes[idx].type
# :Curve   [Date]   (Close)

# %%
all_tickers = ticker_df.Ticker.unique().tolist()

# %%
all_tickers
# Out:
# ['PTON', 'TDOC', 'ZM']

# %%
def dataframes_for_tickers(symbols):
    dfs = list()
    for symbol in symbols:
        ticker_df[ticker_df['Ticker'] == symbol]
    return dfs

# %%
dataframes_for_tickers("PTON ZM".split())
# Out:
# [                  Open        High        Low       Close   Adj Close  \
#  Date
#  2020-01-02   28.900000   30.020000  27.799999   29.740000   29.740000
#  2020-01-03   29.490000   31.250000  29.290001   30.600000   30.600000
#  2020-01-06   30.610001   31.705000  29.719999   29.750000   29.750000
#  2020-01-07   29.440001   30.840000  28.830000   30.400000   30.400000
#  2020-01-08   30.070000   30.250000  28.850000   29.650000   29.650000
#  ...                ...         ...        ...         ...         ...
#  2021-09-01   99.910004  101.750000  98.290001  100.040001  100.040001
#  2021-09-02  100.179001  102.279999  99.559998  101.000000  101.000000
#  2021-09-03  100.860001  101.349998  96.949997   98.559998   98.559998
#  2021-09-07   98.099998   98.889999  96.055000   96.480003   96.480003
#  2021-09-08   96.200996   99.120003  96.059998   97.500000   97.500000
#
#               Volume Ticker
#  Date
#  2020-01-02  5916200   PTON
#  2020-01-03  4974100   PTON
# ...

# %%
def merge_dfs(dfs):
    if len(dfs) == 1:
        return dfs
    left = dfs[0]
    for df in dfs[1:]:
        left = left.merge(df, on='Date')
    return left

# %%
_ = dataframes_for_tickers("PTON ZM".split())

# %%
_
# Out:
# [                  Open        High        Low       Close   Adj Close  \
#  Date
#  2020-01-02   28.900000   30.020000  27.799999   29.740000   29.740000
#  2020-01-03   29.490000   31.250000  29.290001   30.600000   30.600000
#  2020-01-06   30.610001   31.705000  29.719999   29.750000   29.750000
#  2020-01-07   29.440001   30.840000  28.830000   30.400000   30.400000
#  2020-01-08   30.070000   30.250000  28.850000   29.650000   29.650000
#  ...                ...         ...        ...         ...         ...
#  2021-09-01   99.910004  101.750000  98.290001  100.040001  100.040001
#  2021-09-02  100.179001  102.279999  99.559998  101.000000  101.000000
#  2021-09-03  100.860001  101.349998  96.949997   98.559998   98.559998
#  2021-09-07   98.099998   98.889999  96.055000   96.480003   96.480003
#  2021-09-08   96.200996   99.120003  96.059998   97.500000   97.500000
#
#               Volume Ticker
#  Date
#  2020-01-02  5916200   PTON
#  2020-01-03  4974100   PTON
# ...
